# %% [markdown]
# # Homework 01: Data, Expressions, and Variables
#
# This homework practices the ideas from Lecture 01: numbers, variables, arithmetic operators, comparison operators, and Boolean logic.
#
# Start with the code traces. For each trace, predict what the code prints and write your answer as `print(...)` lines in the answer cell.
#
# After that, solve the programming problems. Each programming problem gives you a function. Use the parameter names like normal variables, then `return` the answer.
#
# Do not change the function names or parameter names. Only replace `pass` with your own code.

# %% [markdown]
# ## Setup
#
# Run this cell first. It finds the project folder and imports the homework checker.

# %%
import sys
from pathlib import Path

sys.dont_write_bytecode = True

def find_project_root():
    for path in (Path.cwd(), *Path.cwd().parents):
        if (path / "course_utils").is_dir() and (path / "pyproject.toml").is_file():
            return path
    raise RuntimeError(
        "Could not find the project root. Open the yisen-coding folder in VS Code, "
        "or start Jupyter with `uv run jupyter lab` from the yisen-coding folder."
    )

print("Initializing the project paths.")

PROJECT_ROOT = find_project_root()
HOMEWORK_DIR = PROJECT_ROOT / "homework" / "hw01"

print(f"Found project root: {PROJECT_ROOT}")

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Successfully added the root to path.")

from course_utils.notebook_check import check, trace

CASES = "homework.hw01.tests.cases"
TRACES = "homework.hw01.tests.traces"

print("Successfully loaded the homework checker.")
print("Happy Coding!")

# %% [markdown]
# ## Code Traces
#
# For each trace, read the code and predict the exact printed output. In the answer cell, write one `print(...)` line for each line of output.
#
# Trace checks only tell you AC or WA. They do not show the expected answer.

# %% [markdown]
# ### Code Trace 1
#
# What does the following code print?
#
# ```python
# print(673 % 1)
# print(673 % 10)
# print(673 % 100)
# print(673 % 1000)
# ```

# %%
@trace("mod_remainders", TRACES)
def mod_remainders():
    # TODO: write one print(...) line for each line of output.
    pass

# %% [markdown]
# ### Code Trace 2
#
# What does the following code print?
#
# ```python
# print(263 // 1)
# print(263 // 10)
# print(263 // 100)
# print(263 // 1000)
# ```

# %%
@trace("floor_division", TRACES)
def floor_division():
    # TODO: write one print(...) line for each line of output.
    pass

# %% [markdown]
# ### Code Trace 3
#
# What does the following code print?
#
# ```python
# x = -5
# y = 3
# print(x + y >= -3)
# print(not (x + y >= -3))
# print((x <= 8) and (x == y))
# print(not ((x <= 8) or (x == y)))
# ```

# %%
@trace("boolean_logic_a", TRACES)
def boolean_logic_a():
    # TODO: write one print(...) line for each line of output.
    pass

# %% [markdown]
# ### Code Trace 4
#
# What does the following code print?
#
# ```python
# x = 4
# print(x)
# x **= 2
# print(x)
# y = 13
# print(7 * (x - y) // 2)
# ```

# %%
@trace("exponent_update", TRACES)
def exponent_update():
    # TODO: write one print(...) line for each line of output.
    pass

# %% [markdown]
# ### Code Trace 5
#
# What does the following code print?
#
# ```python
# x = '8'
# print(type(x) == int)
# y = 5
# print(type(y) == int)
# z = 1.0
# print(type(z) == int)
# ```

# %%
@trace("type_checks", TRACES)
def type_checks():
    # TODO: write one print(...) line for each line of output.
    pass

# %% [markdown]
# ### Code Trace 6
#
# What does the following code print?
#
# ```python
# n = 618
# print(n % 2)
# n += 1
# print(n % 2)
# print(n / 10)
# n //= 10
# print(n)
# ```

# %%
@trace("update_number", TRACES)
def update_number():
    # TODO: write one print(...) line for each line of output.
    pass

# %% [markdown]
# ### Code Trace 7
#
# What does the following code print?
#
# ```python
# x = -6
# y = 3
# print(x + y >= -2)
# print((x < 4) and (x == y))
# print(not ((x != y) or (y <= 6)))
# ```

# %%
@trace("boolean_logic_b", TRACES)
def boolean_logic_b():
    # TODO: write one print(...) line for each line of output.
    pass

# %% [markdown]
# ### Code Trace 8
#
# What does the following code print?
#
# ```python
# # Hints:
# # str(52) converts the integer 52 into the string '52'
# # int('52') converts the string '52' into the integer 52
#
# m = 47
# n = m / 1
# print(type(m) == int, type(n) == int)
# x = int(2 * str(2 * int('2'))) + 3
# b = (x % 2 == 1)
# print(x, b)
# print(int(b), int(not b))
# ```

# %%
@trace("conversions", TRACES)
def conversions():
    # TODO: write one print(...) line for each line of output.
    pass

# %% [markdown]
# ## Programming Problems
#
# For each programming problem, replace `pass` with a `return` statement. Run the cell to see the checker feedback.

# %% [markdown]
# ## Problem 1: Double a Number
#
# Write a function named `double` that takes a number and returns twice that number.
#
# Examples:
# - `double(3)` should return `6`
# - `double(-4)` should return `-8`

# %%
@check("double", CASES)
def double(number):
    # TODO: replace pass with your answer.
    pass

# %% [markdown]
# ## Problem 2: Rectangle Area
#
# Write a function named `rectangle_area` that takes a rectangle's `width` and `height`, then returns the area.
#
# Area means `width * height`.

# %%
@check("rectangle_area", CASES)
def rectangle_area(width, height):
    # TODO: replace pass with your answer.
    pass

# %% [markdown]
# ## Problem 3: Average Score
#
# Write a function named `average_score` that takes two scores and returns their average.
#
# Remember the logical-error example from lecture: use parentheses so Python adds the two scores before dividing by `2`.

# %%
@check("average_score", CASES)
def average_score(score1, score2):
    # TODO: replace pass with your answer.
    pass

# %% [markdown]
# ## Problem 4: Full Groups
#
# Write a function named `full_groups` that returns how many full groups can be made.
#
# For example, if there are `23` cards and each player gets `7`, then there are `3` full groups because `23 // 7` is `3`.

# %%
@check("full_groups", CASES)
def full_groups(items, group_size):
    # TODO: replace pass with your answer.
    pass

# %% [markdown]
# ## Problem 5: Is Even
#
# Write a function named `is_even` that returns `True` when a number is even and `False` when it is odd.
#
# Hint: even numbers have remainder `0` when divided by `2`.

# %%
@check("is_even", CASES)
def is_even(number):
    # TODO: replace pass with your answer.
    pass

# %% [markdown]
# ## Challenge 1: Total Seconds
#
# Write a function named `total_seconds` that takes `hours`, `minutes`, and `seconds`, then returns the total number of seconds.
#
# Useful facts:
# - 1 hour is 3600 seconds
# - 1 minute is 60 seconds

# %%
@check("total_seconds", CASES)
def total_seconds(hours, minutes, seconds):
    # TODO: replace pass with your answer.
    pass

# %% [markdown]
# ## Challenge 2: Contest Entry
#
# Write a function named `can_enter_contest` that returns whether someone can enter a contest.
#
# A person can enter only if all three rules are true:
# - their age is at least `10`
# - their score is at least `80`
# - they have permission
#
# Return a Boolean value: `True` or `False`.

# %%
@check("can_enter_contest", CASES)
def can_enter_contest(age, score, has_permission):
    # TODO: replace pass with your answer.
    pass

# %% [markdown]
# ## Final Check
#
# Save the notebook first. Then run the next cell to run the official pytest checks from inside Jupyter.
#
# The marker in the next cell tells GitHub's notebook loader to skip this cell, because GitHub already runs pytest from the command line.

# %%
# PYTEST-SKIP
import sys

import pytest

sys.dont_write_bytecode = True

test_path = HOMEWORK_DIR / "tests"

pytest.main(["--assert=plain", "-q", str(test_path)])
